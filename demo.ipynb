# %%
from hello_agents import SimpleAgent, HelloAgentsLLM
from dotenv import load_dotenv

# 加载环境变量
load_dotenv()

# 创建LLM实例 - 框架自动检测provider
llm = HelloAgentsLLM()

# 或手动指定provider（可选）
# llm = HelloAgentsLLM(provider="modelscope")

# 创建SimpleAgent
agent = SimpleAgent(
    name="AI助手",
    llm=llm,
    system_prompt="你是一个有用的AI助手"
)

# 基础对话
response = agent.run("你好！请介绍一下自己")
print(response)

# 添加工具功能（可选）
from hello_agents.tools import CalculatorTool
calculator = CalculatorTool()
# 需要实现7.4.1的MySimpleAgent进行调用，后续章节会支持此类调用方式
# agent.add_tool(calculator)

# 现在可以使用工具了
response = agent.run("请帮我计算 2 + 3 * 4")
print(response)

# 查看对话历史
print(f"历史消息数: {len(agent.get_history())}")
# Out:
# 🧠 正在调用 llama3.2:1b 模型 (非流式)...
# 我是一个由开源的 conversational AI（人机沟通模拟器）框架打造好的智能小助手。 我的主要功能包括：
#
# - 语法分析和处理
# - 语句规划和生成
# - 数据分析和预测
# - 问答和信息提供
# - 任务分发和调度
#
# 我使用的是开源的 transformers 语言模型作为基础，能够理解自然语言，并且有能力进行多种类型的计算。 我还可以通过学习和更新 myself 的方式来提升我的知识和技能。
#
# 我目前正在向用户提供关于各种主题的信息和指导。 但是请注意，我 Still 在不断学习和改进，因此可能有一些功能不全或问题。
#
# 您想从哪里开始交流吗？
# 🧠 正在调用 llama3.2:1b 模型 (非流式)...
# 计算器！
#
# 给定表达式：2 + 3 * 4
#
# 在计算器中，首先执行乘法运算：3 * 4 = 12。
#
# 然后，根据加法规则，再次执行乘法运算：2 + 12 = 14。
#
# 最后，结果为：2 + 3 * 4 = 14
# 历史消息数: 4
